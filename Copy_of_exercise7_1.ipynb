# %% [markdown]
# <a href="https://colab.research.google.com/github/Manos-Mak120/Makrakis-Manos/blob/main/Copy_of_exercise7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Σκοπός αυτής της άσκησης είναι να φτιάξετε scrapers για 9 sites (ENA ο καθένας/καθεμιά).
#
# Με αυτό τον τρόπο, θα έχετε όλοι μαζί, 10 scrapers (μαζί με αυτόν που έφτιαξα εγώ για την καθημερινή), έναν για καθένα από 10 διαφορετικά sites. Έτσι, θα μπορείτε να τους χρησιμοποιήσετε για να φέρετε δεδομένα από διαφορετικά sites, σχετικά με το θέμα που θα διαλέξετε για την τελική σας εργασία, ώστε να μπορείτε να κάνετε συγκρίσεις.

# %% [markdown]
# Για να φτιάξετε τον scraper, μελετήστε και ακολουθήστε τα βήματα κατασκευής scraper που περιγράφονται σε αυτό το notebook: https://colab.research.google.com/drive/1F5DB56h9YcFXcnkr3b6y_0W63XjJ1mCI?usp=sharing
#
# Εκεί περιγράφεται λεπτομερώς ένας τρόπος κατασκευής ενός scraper για όλα (περίπου) τα teaser pages της Καθημερινής.
#
# **Το τελικό αποτέλεσμα της εργασίας σας θα είναι σαν τον scraper της Kαθημερινής** που θα βρείτε εδώ: https://colab.research.google.com/drive/112h9nSqAf9lLhez_ABd8ARx0Ks23eczu?usp=sharing

# %% [markdown]
# Επειδή όπως είπαμε (και θα διαβάσετε και στο notebook) δεν σκραπάρονται όλα τα sites με το requests και για να μην ψάχνετε και χαωθείτε, σας παραθέτω 14 sites με τα οποία μπορείτε να δουλέψετε.

# %% [markdown]
# Ο παρακάτω κώδικας μπαίνει σε ένα-ένα όλα τα 14 sites, φέρνει την πρώτη σελίδα που έχει όλα τα άρθρα και εφόσον όλα πάνε καλά μετράει πόσα άρθρα έχει η σελίδα.

# %%
import requests
from bs4 import BeautifulSoup

# %%
sites_urlsL = ["https://www.newsit.gr/eidhseis-tora/page/1/",
               "https://www.naftemporiki.gr/newsroom/page/1/",
               "https://www.dnews.gr/oles-oi-eidiseis?start=0",
               "https://www.newsbomb.gr/oles-oi-eidhseis?page=1",
               "https://www.lifo.gr/now?_wrapper_format=html&page=0",
               "https://www.documentonews.gr/arxiki-selida/roi-eidiseon/page/1",
               "https://www.tovima.gr/latest-news/page/1/",
               "https://www.tanea.gr/allnews/page/1/",
               "https://www.in.gr/latestnews/page/1/",
               "https://www.iefimerida.gr/eidiseis?page=1",
               "https://www.thetoc.gr/newsfeed/?page=1",
               "https://www.athensvoice.gr/epikairotita/news/?pg=1",
               "https://www.parapolitika.gr/roi-eidiseon/?pg=1",
               "https://www.zougla.gr/ola/page/1/"]

# %%
def get_webpage_soup(url):
  headers = {
        "User-Agent": "Mozilla/5.0"
    }
  response = requests.get(url, headers=headers)
  if response.status_code != 200:
    print(f"Error: {response.status_code}")
    return None
  else:
    print(f"{url} was scraped successfully")
    return BeautifulSoup(response.text, 'html.parser')

# %%
soup = BeautifulSoup

# %%
for site_url in sites_urlsL:
  soup = get_articles_data(site_url)
  if "newsit.gr" in site_url:
    articlesL = soup.find_all("article")
  elif "naftemporiki.gr" in site_url:
    articlesL = soup.find_all("div", {"class": "item item-stream position-relative"})
  elif "dnews.gr" in site_url:
    articlesL = soup.find_all("div", class_=lambda c: c and "item primary" in c or c and "item leading" in c)
  elif "newsbomb.gr" in site_url:
    articlesL = soup.find_all("article")
  elif "lifo.gr" in site_url:
    articlesL = soup.find_all("article", {"class": "row no-gutters mb-4 mb-lg-6"})
  elif "documentonews.gr" in site_url:
    articlesL = soup.find_all("div", {"class": "item post loop"})
  elif "tovima.gr" in site_url:
    articlesL = soup.find_all("div", {"class": "column is-full wrap-category-row"})
  elif "tanea.gr" in site_url:
    articlesL = soup.find("div", {"class": "main-archive-articles"}).find_all("div", {"class": "column is-full"})
  elif "in.gr" in site_url:
    articlesL = soup.find_all("article")
  elif "iefimerida.gr" in site_url:
    articlesL = soup.find_all("article")
  elif "thetoc.gr" in site_url:
    articlesL = soup.find_all("div", {"class": "item-content"})
  elif "athensvoice.gr" in site_url:
    articlesL = soup.find("div", {"class": "articles articles--singleColumn articles--large"}).find_all("article")
  elif "parapolitika.gr" in site_url:
    articlesL = soup.find_all("article")
  elif "zougla.gr" in site_url:
    articlesL = soup.find_all("div", {"class": "article-wrapper"})
  else:
    print(f"{site_url} not found")
  print(f"{site_url}: {len(articlesL)} articles")
# Out:
# https://www.newsit.gr/eidhseis-tora/page/1/: 17 articles
# https://www.naftemporiki.gr/newsroom/page/1/: 30 articles
# https://www.dnews.gr/oles-oi-eidiseis?start=0: 31 articles
# https://www.newsbomb.gr/oles-oi-eidhseis?page=1: 30 articles
# https://www.lifo.gr/now?_wrapper_format=html&page=0: 20 articles
# https://www.documentonews.gr/arxiki-selida/roi-eidiseon/page/1: 10 articles
# https://www.tovima.gr/latest-news/page/1/: 20 articles
# https://www.tanea.gr/allnews/page/1/: 30 articles
# https://www.in.gr/latestnews/page/1/: 30 articles
# https://www.iefimerida.gr/eidiseis?page=1: 10 articles
# https://www.thetoc.gr/newsfeed/?page=1: 11 articles
# https://www.athensvoice.gr/epikairotita/news/?pg=1: 10 articles
# https://www.parapolitika.gr/roi-eidiseon/?pg=1: 40 articles
# https://www.zougla.gr/ola/page/1/: 18 articles

# %% [markdown]
# Επίσης, προς διευκόλυνσή σας, έχω βρεί το tag/class για το block των άρθρων σε κάθε site, οπότε θα πάρετε τον κώδικα για το articlesL από το παραπάνω cell, ανάλογα με το site που θα δουλέψετε.

# %% [markdown]
# Από την παραπάνω λίστα με τα sites θα πάρετε το url του πρώτου page της σελίδας με όλα τα άρθρα για το site που θα δουλέψετε.

# %% [markdown]
# Μελετήστε μια φορά το notebook-οδηγό τρέχοντας όλα τα κελιά απ' την αρχή ως το τέλος και ΑΦΟΥ ΤΟ ΚΑΝΕΤΕ ΑΥΤΟ, φτιάξτε ένα αντίγραφο του notebook και αρχίστε να κάνετε τις αλλαγές που χρειάζονται.
#
# Θα βάλετε το url του site που διαλέξατε, τον κώδικα του articlesL και το μόνο που έχετε να κάνετε είναι να βρείτε τα tags/sections για τα elements των δεδομένων που φέρουν τα άρθρα.
#
# Καλό θα ήταν να φτιάξετε έναν ολοκληρωμένο scraper που θα δουλεύει δηλαδή και στις σελίδες των κατηγοριών και της αναζήτησης (ιδιαίτερα της αναζήτησης), αλλά αν κουραστείτε κάνετε έστω τον scraper να δουλεύει σωστά για τις σελίδες με όλα τα άρθρα.

# %% [markdown]
# # ΓΙΑ ΝΑ ΔΙΑΣΦΑΛΙΣΟΥΜΕ ΟΤΙ ΔΕΝ ΘΑ ΚΑΝΕΤΕ 2 ΑΤΟΜΑ ΤΟ ΙΔΙΟ SITE,
#
# δηλώστε εδώ ποιο site δουλεύετε και επιλέξτε να δουλέψετε με ένα site που δεν έχει δηλώσει άλλος/άλλη: https://docs.google.com/spreadsheets/d/1onHp3ua1944SJGrBXVt3zJ16wrWMUBZOM2PD4AQtK50/edit?usp=sharing

# %%
pg=1

# %%
url=f"https://www.newsbomb.gr/oles-oi-eidhseis/?pg={pg}"

# %%
soup = get_webpage_soup(url)
# Out:
# https://www.newsbomb.gr/oles-oi-eidhseis/?pg=1 was scraped successfully
# <!DOCTYPE html>
#
# <html class="main-site" lang="el">
# <head>
# <meta charset="utf-8"/>
# <base href="https://www.newsbomb.gr/oles-oi-eidhseis"/>
# <meta content="Ροή Ειδήσεων, Ειδήσεις Τώρα, News, τελευταία νέα" name="news_keywords"/>
# <meta content="index, follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="light dark" name="color-scheme"/>
# <meta content="Όλες οι ειδήσεις και η έκτακτη επικαιρότητα σήμερα." name="description"/>
# <meta content="Joomla! - Open Source Content Management" name="generator"/>
# <title>Όλες οι ειδήσεις</title>
# <link href="https://www.newsbomb.gr/oles-oi-eidhseis" rel="canonical"/>
# <link href="https://www.newsbomb.gr/oles-oi-eidhseis?format=feed&amp;type=rss" rel="alternate" title="RSS 2.0" type="application/rss+xml"/>
# <link href="https://www.newsbomb.gr/oles-oi-eidhseis?format=feed&amp;type=atom" rel="alternate" title="Atom 1.0" type="application/atom+xml"/>
# <link href="https://img.bbmd.gr" rel="preconnect"/>
# <link href="https://img.bbmd.gr/assets/device/favicon-48x48.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://img.bbmd.gr/assets/device/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://img.bbmd.gr/assets/device/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://img.bbmd.gr/assets/device/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://img.bbmd.gr/assets/device/icon-192x192.png" rel="shortcut icon" sizes="192x192" type="image/png"/>
# <link crossorigin="use-credentials" href="https://www.newsbomb.gr/manifest.json" rel="manifest"/>
# <script defer="" src="https://staticnb.bbend.net/scripts/0.6.11/main/js/site/main.min.js"></script>
# <script async="" defer="" src="/media/plg_captcha_recaptcha_invisible/js/recaptcha.min.js?cfe035c6240f266535fd5939b94d6bed"></script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js?onload=JoomlaInitReCaptchaInvisible&amp;render=explicit&amp;hl=el"></script>
# <meta content="https://www.facebook.com/newsbombgr" property="article:publisher"/>
# <meta content="Newsbomb" property="og:site_name"/>
# <meta content="https://www.newsbomb.gr/oles-oi-eidhseis" property="og:url"/>
# <meta content="Όλες οι ειδήσεις - Newsbomb" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="Όλες οι ειδήσεις και η έκτακτη επικαιρότητα σήμερα." property="og:description"/>
# <meta content="https://img.bbmd.gr/img/1200/max/90/2024/07/03/Newsbomb-gategory-oles-oi-eidhseis-og.jpg?t=jCygQVUUu0Z8obwne5ftuw" property="og:image"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="@newsbombgr" property="twitter:site"/>
# <meta content="https://www.newsbomb.gr" property="twitter:domain"/>
# <meta content="@newsbombgr" property="twitter:creator"/>
# <meta content="Όλες οι ειδήσεις - Newsbomb" property="twitter:title"/>
# <meta content="Όλες οι ειδήσεις και η έκτακτη επικαιρότητα σήμερα." property="twitter:description"/>
# <meta content="https://img.bbmd.gr/img/1200/max/90/2024/07/03/Newsbomb-gategory-oles-oi-eidhseis-og.jpg?t=jCygQVUUu0Z8obwne5ftuw" property="twitter:image"/>
# <meta content="https://www.newsbomb.gr/oles-oi-eidhseis" property="twitter:url"/>
# <meta content="2449087102110668" property="fb:app_id"/>
# <meta content="134135906635470" property="fb:pages"/>
# <script class="joomla-script-options new" type="application/json">
# {"modules":[{"name":"Header","options":{"breakpoint":620,"seconds":3}},{"name":"Togglers","options":[]},{"name":"Cmp","options":{"google":true,"prebid":true,"png":true,"tempo":true,"exitbee":true,"butterfly":false,"agora":true,"preroll":false,"groupm":true,"unilever":true,"nielsen":false,"textlinks":true,"smartAdserver":true}},{"name":"Global","options":[]},{"name":"ReadingList","options":[]},{"name":"RFVTracker","options":{"recencyScores":[[15,30],[8,14],[2,7],[0,1]],"frequencyScores":[[1,2],[3,6],[7,12],[13,1000000]],"volumeScores":[[1,4],[5,10],[11,20],[21,1000000]]}},{"name":"Members","options":[]},{"name":"Newsletter","options":{"selector":"#module-148","messages":{"success":"Ευχαριστούμε για την εγγραφή. Θα λάβετε email επιβεβαίωσης.","failure":"Παρουσιάστηκε πρόβλημα, δοκιμάστε ξανά σε μερικά λεπτά"}}}]}
# </script>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Geologica:wght@300;400;500;600;700;900&amp;display=swap" rel="stylesheet"/>
# <style>:root{--color-scheme:dark light;--background:white;--white:#fff;--transparent-one:#FFFFFF1A;--transparent-two:#FFFFFF00;--primary:#000;--primary-90:#1e1e1e;--primary-70:#464646;--primary-50:gray;--primary-20:#CDCDCD;--primary-07:#ebebeb;--primary-02:#fafafa;--secondary:#29324A;--accent-blue:#344f97;--dark-blue:#29324A;--dark-blue:#273b71;--blue:#0b1e6e;--light-blue:#f0f2f4;--dark-red:#C31A20;--light-red:#EA4335;--azure-blue:#007FFF;--basic-max-width:90em;--safe-max-width:85em;--big-max-width:110em;--font-headline:'Geologica','Helvetica',Arial,sans-serif;--font-label:'Trebuchet MS',sans-serif;--font-system:-apple-system,BlinkMacSystemFont,'Segoe UI','Roboto','Oxygen-Sans','Ubuntu','Cantarell','Helvetica Neue',sans-serif,'Apple Color Emoji','Segoe UI Emoji','Segoe UI Symbol'}@media screen and (min-width:2100px){:root{--basic-max-width:95em;--big-max-width:115em}}html,body,div,span,applet,object,iframe,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,img,ins,kbd,q,s,samp,small,strike,strong,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block}ol,ul{list-style:none}blockquote,q{quotes:none}html{color-scheme:dark light}body{font-family:var(--font-system);font-size:16px;line-height:1.5;background:var(--background);color:var(--primary);-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:none}h1,h2,h3,h4,h5,h6{font-family:var(--font-headline)}h1{font-size:1.65em;line-height:1.25;font-weight:700}h2{font-size:1.5em;line-height:1.125;font-weight:900}h3{font-size:1.25em;line-height:1.1;font-weight:700}h4{font-size:1em;line-height:1.3;font-weight:600}h5{font-weight:400;font-size:.8em;line-height:1.6}h6{font-weight:400;font-size:.875em;line-height:1.125em}a{color:var(--dark-red)}a:focus{--outline:0}p{margin:0;padding:0}table{border-collapse:collapse;border-spacing:0}input:focus{outline:none}svg{fill:var(--primary-90)}.logo-path{fill:var(--dark-red)}.logo-circle{fill:var(--dark-red)}@media (prefers-color-scheme:dark){:root{--background:#181818;--primary:#d9d9d9;--primary-90:#ccc;--primary-70:#4d4d4d;--primary-20:#252525;--primary-07:#232323;--primary-02:#202020;--accent-blue:#3b59aa;--secondary:#8A92AF;--dark-blue:#373C4A;--dark-blue:#273b71;--light-blue:#4E4F50;--dark-red:#C31A20}input{background:white;color:#1e1e1e}.block-head svg{fill:var(--primary-90)}.logo-path{fill:var(--primary-90)}}.menu-opened body{--overflow-y:hidden}.page-section{margin-inline:auto;box-sizing:border-box;background:var(--background)}.has-skin .page-section{position:relative}.top-gap{padding-top:3em}.bottom-gap{margin-bottom:3em}.lines{border-top:1px solid var(--primary-07);border-left:1px solid var(--primary-07)}@media (prefers-color-scheme:light){.icon-arrow{fill:var(--dark-blue)}}.icon-arrow.arrow-top-right{transform:rotate(-45deg)}.icon-arrow.arrow-left{transform:rotate(-180deg)}.block-tabs{margin:2.5rem auto;border-left:1px solid var(--primary-07)}.block-tabs .tabs{width:100%;justify-content:space-evenly;display:flex}.block-tabs .tab{min-height:3.25em;display:flex;align-items:center;gap:.3em;flex:1 1 100%;justify-content:center;background:var(--primary-02);position:relative;border-right:1px solid var(--primary-07);border-top:1px solid var(--primary-07);border-bottom:1px solid var(--primary-07)}.block-tabs .tab.tab-active{font-weight:700;background:var(--background);color:var(--dark-red);--border-bottom:0}.block-tabs .tab.tab-active:before{content:'';display:block;height:4px;background:var(--dark-red);position:absolute;top:-4px;left:0;right:0}.block-tabs .tab svg{margin-right:.3em}.block-tabs .tab svg.icon-trending{margin-right:.2em}.block-tabs .tab.tab-active svg{ ...
# <!-- index -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-E89HHTW34H"></script>
# <script>
#
# 	var hit_source = 'none';
# 	var hit_medium = 'none';
# 	var hit_campaign= 'none';
# 	if (typeof URL === "function" && document.referrer) {
#
# 		var doc_location = new URL(document.location);
# 		var doc_referrer = new URL(document.referrer);
#
# 		if (doc_location.hostname !== doc_referrer.hostname) {
# 			hit_source = doc_referrer.hostname;
# 			localStorage.setItem('nb_hit_source', hit_source);
# 		}
#
# 		var params = doc_location.searchParams;
# 		let utm_medium = params.get('utm_medium');
# 		if (utm_medium) {
# 			hit_medium = utm_medium;
# 			localStorage.setItem('nb_hit_medium', hit_medium);
# 		}
#
# 		let utm_campaign = params.get('utm_campaign');
# 		if (utm_campaign) {
# 			hit_campaign = utm_campaign;
# 			localStorage.setItem('nb_hit_campaign', hit_campaign);
# 		}
# 	}
#
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
#
# 	gtag('config', 'G-E89HHTW34H', {
# 		'hit_source': hit_source,
# 		'hit_medium': hit_medium,
# 		'page_id': '0ee69fb92644bf4fefc15cf76ddff355'
# 	});
#
#
# 	gtag('config', 'G-HRJMPC4ZXT');
#
# </script>
# <script>
# (function() {
# 	var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
# 	_sf_async_config.uid = 63844;
# 	_sf_async_config.domain = 'newsbomb.gr';
# 	_sf_async_config.useCanonical = false;
# 	_sf_async_config.useCanonicalDomain = false;
# 	_sf_async_config.path = 'newsbomb.gr/oles-oi-eidhseis';
# 	_sf_async_config.flickerControl = false;
# 	_sf_async_config.sections = 'oles-oi-eidhseis';
# 		_sf_async_config.type = 'category';
#
# 	function loadChartbeat() {
# 		var e = document.createElement('script');
# 		var n = document.getElementsByTagName('script')[0];
# 		e.type = 'text/javascript';
# 		e.async = true;
# 		e.src = '//static.chartbeat.com/js/chartbeat.js';
# 		n.parentNode.insertBefore(e, n);
# 	}
# 	loadChartbeat();
# 	})();
# </script>
# <!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script>
# (function() {
#   var host = window.location.hostname;
#   var element = document.createElement('script');
#   var firstScript = document.getElementsByTagName('script')[0];
#   var url = 'https://cmp.inmobi.com'
#     .concat('/choice/', 'eLT_jqyFg7ftW', '/', host, '/choice.js?tag_version=V3');
#   var uspTries = 0;
#   var uspTriesLimit = 3;
#   element.async = true;
#   element.type = 'text/javascript';
#   element.src = url;
#
#   firstScript.parentNode.insertBefore(element, firstScript);
#
#   function makeStub() {
#     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#     var queue = [];
#     var win = window;
#     var cmpFrame;
#
#     function addFrame() {
#       var doc = win.document;
#       var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#       if (!otherCMP) {
#         if (doc.body) {
#           var iframe = doc.createElement('iframe');
#
#           iframe.style.cssText = 'display:none';
#           iframe.name = TCF_LOCATOR_NAME;
#           doc.body.appendChild(iframe);
#         } else {
#           setTimeout(addFrame, 5);
#         }
#       }
#       return !otherCMP;
#     }
#
#     function tcfAPIHandler() {
#       var gdprApplies;
#       var args = arguments;
#
#       if (!args.length) {
#         return queue;
#       } else if (args[0] === 'setGdprApplies') {
#         if (
#           args.length > 3 &&
#           args[2] === 2 &&
#           typeof args[3] === 'boolean'
#         ) {
#           gdprApplies = args[3];
#           if (typeof args[2] === 'function') {
#             args[2]('set', true);
#           }
#         }
#       } else if (args[0] === 'ping') {
#         var retr = {
#           gdprApplies: gdprApplies,
#           cmpLoaded: false,
#           cmpStatus: 'stub'
#         };
#
#         if (typeof args[2] === 'function') {
#           args[2](retr);
#         }
#       } else {
#         if(args[0] === 'init' && typeof args[3] === 'object') {
#           args[3] = Object.assign(args[3], { tag_version: 'V3' });
#         }
#         queue.push(args);
#       }
#     }
#
#     function postMessageEventHandler(event) {
#       var msgIsString = typeof event.data === 'string';
#       var json = {};
#
#       try {
#         if (msgIsString) {
#           json = JSON.parse(event.data);
#         } else {
#           json = event.data;
#         }
#       } catch (ignore) {}
#
#       var payload = json.__tcfapiCall;
#
#       if (payload) {
#         window.__tcfapi(
#           payload.command,
#           payload.version,
#           function(retValue, success) {
#             var returnMsg = {
#               __tcfapiReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: payload.callId
#               }
#             };
#             if (msgIsString) {
#               returnMsg = JSON.stringify(returnMsg);
#             }
#             if (event && event.source && event.source.postMessage) {
#               event.source.postMessage(returnMsg, '*');
#             }
#           },
#           payload.parameter
#         );
#       }
#     }
#
#     while (win) {
#       try {
#         if (win.frames[TCF_LOCATOR_NAME]) {
#           cmpFrame = win;
#           break;
#         }
#       } catch (ignore) {}
#
#       if (win === window.top) {
#         break;
#       }
#       win = win.parent;
#     }
#     if (!cmpFrame) {
#       addFrame();
#       win.__tcfapi = tcfAPIHandler;
#       win.addEventListener('message', postMessageEventHandler, false);
#     }
#   };
#
#   makeStub();
#
#   function makeGppStub() {
#     const CMP_ID = 10;
#     const SUPPORTED_APIS = [
#       '2:tcfeuv2',
#       '6:uspv1',
#       '7:usnatv1',
#       '8:usca',
#       '9:usvav1',
#       '10:uscov1',
#       '11:usutv1',
#       '12:usctv1'
#     ];
#
#     window.__gpp_addFrame = function (n) {
#       if (!window.frames[n]) {
#         if (document.body) {
#           var i = document.createElement("iframe");
#           i.style.cssText = "display:none";
#           i.name = n;
#           document.body.appendChild(i);
#         } else {
#           window.setTimeout(window.__gpp_addFrame, 10, n);
#         }
#       }
#     };
#     window.__gpp_stub = function () {
#       var b = arguments;
#       __gpp.queue = __gpp.queue || [];
#       __gpp.events = __gpp.events || [];
#
#       if (!b.length || (b.length == 1 && b[0] == "queue")) {
#         return __gpp.queue;
#       }
#
#       if (b.length == 1 && b[0] == "events") {
#         return __gpp.events;
#       }
#
#       var cmd = b[0];
#       var clb = b.length > 1 ? b[1] : null;
#       var par = b.length > 2 ? b[2] : null;
#       if (cmd === "ping") {
#         clb(
#           {
#             gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#             cmpStatus: "stub", // possible values: stub, loading, loaded, error
#             cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#             signalStatus: "not ready", // possible values: not ready, ready
#             supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#             cmpId: CMP_ID, // IAB assigned CMP ID, may be 0 during stub/loading
#             sectionList: [],
#             applicableSections: [-1],
#             gppString: "",
#             parsedSections: {},
#           },
#           true
#         );
#       } else if (cmd === "addEventListener") {
#         if (!("lastId" in __gpp)) {
#           __gpp.lastId = 0;
#         }
#         __gpp.lastId++;
#         var lnr = __gpp.lastId;
#         __gpp.events.push({
#           id: lnr,
#           callback: clb,
#           parameter: par,
#         });
#         clb(
#           {
#             eventName: "listenerRegistered",
#             listenerId: lnr, // Registered ID of the listener
#             data: true, // positive signal
#             pingData: {
#               gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#               cmpStatus: "stub", // possible values: stub, loading, loaded, error
#               cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#               signalStatus: "not ready", // possible values: not ready, ready
#               supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#               cmpId: CMP_ID, // list of supported APIs
#               sectionList: [],
#               applicableSections: [-1],
#               gppString: "",
#               parsedSections: {},
#             },
#           },
#           true
#         );
#       } else if (cmd === "removeEventListener") {
#         var success = false;
#         for (var i = 0; i < __gpp.events.length; i++) {
#           if (__gpp.events[i].id == par) {
#             __gpp.events.splice(i, 1);
#             success = true;
#             break;
#           }
#         }
#         clb(
#           {
#             eventName: "listenerRemoved",
#             listenerId: par, // Registered ID of the listener
#             data: success, // status info
#             pingData: {
#               gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#               cmpStatus: "stub", // possible values: stub, loading, loaded, error
#               cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#               signalStatus: "not ready", // possible values: not ready, ready
#               supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#               cmpId: CMP_ID, // CMP ID
#               sectionList: [],
#               applicableSections: [-1],
#               gppString: "",
#               parsedSections: {},
#             },
#           },
#           true
#         );
#       } else if (cmd === "hasSection") {
#         clb(false, true);
#       } else if (cmd === "getSection" || cmd === "getField") {
#         clb(null, true);
#       }
#       //queue all other commands
#       else {
#         __gpp.queue.push([].slice.apply(b));
#       }
#     };
#     window.__gpp_msghandler = function (event) {
#       var msgIsString = typeof event.data === "string";
#       try {
#         var json = msgIsString ? JSON.parse(event.data) : event.data;
#       } catch (e) {
#         var json = null;
#       }
#       if (typeof json === "object" && json !== null && "__gppCall" in json) {
#         var i = json.__gppCall;
#         window.__gpp(
#           i.command,
#           function (retValue, success) {
#             var returnMsg = {
#               __gppReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: i.callId,
#               },
#             };
#             event.source.postMessage(msgIsString ? JSON.stringify(returnMsg) : returnMsg, "*");
#           },
#           "parameter" in i ? i.parameter : null,
#           "version" in i ? i.version : "1.1"
#         );
#       }
#     };
#     if (!("__gpp" in window) || typeof window.__gpp !== "function") {
#       window.__gpp = window.__gpp_stub;
#       window.addEventListener("message", window.__gpp_msghandler, false);
#       window.__gpp_addFrame("__gppLocator");
#     }
#   };
#
#   makeGppStub();
#
#   var uspStubFunction = function() {
#     var arg = arguments;
#     if (typeof window.__uspapi !== uspStubFunction) {
#       setTimeout(function() {
#         if (typeof window.__uspapi !== 'undefined') {
#           window.__uspapi.apply(window.__uspapi, arg);
#         }
#       }, 500);
#     }
#   };
#
#   var checkIfUspIsReady = function() {
#     uspTries++;
#     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#       console.warn('USP is not accessible');
#     } else {
#       clearInterval(uspInterval);
#     }
#   };
#
#   if (typeof window.__uspapi === 'undefined') {
#     window.__uspapi = uspStubFunction;
#     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#   }
# })();
# </script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script>
# window.dfp_targeting = {
#   "site" : "newsbomb",
#   "page_id": "0ee69fb92644bf4fefc15cf76ddff355",
#     "agora" : "true",
#   "phaistos" : "true",
#   "ppn" : "true",
#     "pagetype": "items",
#     "section": "oles-oi-eidhseis",
#       "category": "oles-oi-eidhseis",
#         };
# </script>
# <!-- DFP Settings for items-627 -->
# <script>
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# </script>
# <script>
# 	googletag.cmd.push(function() {
# 		googletag.pubads().setTargeting("site", "newsbomb");
# 		googletag.pubads().setTargeting("page_id", "0ee69fb92644bf4fefc15cf76ddff355");
#
# 		googletag.pubads().setTargeting("agora", "true");
# 	googletag.pubads().setTargeting("phaistos", "true");
# 	googletag.pubads().setTargeting("ppn", "true");
#
# 		googletag.pubads().setTargeting("pageType", "items");
# 		googletag.pubads().setTargeting("pageSection", "oles-oi-eidhseis");
# 		googletag.pubads().setTargeting("pageCategory", "oles-oi-eidhseis");
#
# 				googletag.pubads().disableInitialLoad();
# 				googletag.pubads().enableSingleRequest();
#
# 		// pending ad cookies before this code
#
# 		// if true starts with hidden divs
# 		// googletag.pubads().collapseEmptyDivs();
# 		googletag.pubads().setCentering(true);
#
#
# 		googletag.enableServices();
# 	});
# </script>
# <script>
# 	// this is for ads
# 	window.loadUrl = function(redirectLocation) {
# 		window.top.location = redirectLocation;
# 	}
# 	</script>
# <script async="" src="https://static.cleverpush.com/channel/loader/onytzeXusxeiXewDz.js"></script>
# </head>
# <body class="site basic-header items-view itemid-627 section-627 item-8 ros-page items-default-layout monetizable" id="com_news">
# <svg aria-hidden="true" style="position: absolute; width: 0; height: 0; overflow: hidden;" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
#
57 5.661,3.57C5.661,3.57 5.675,4.248 5.782,5.323L2.037,5.323C1.507,5.323 1.068,5.739 1.039,6.269C1.031,6.422 0.868,10.035 3.548,12.763C4.871,14.109 6.628,14.986 8.794,15.39C9.88,17.131 11.343,18.581 13.313,19.302C13.654,21.735 13.98,26.06 12.198,26.99L9.726,26.99L9.726,29.453L22.284,29.453L22.284,26.99L19.814,26.99C18.054,26.073 18.349,21.848 18.685,19.399C20.73,18.714 22.23,17.201 23.329,15.368" style="fill-rule:nonzero;"></path>
# </symbol>
# <symbol id="eye-open" viewbox="0 0 24 24">
# <path d="M12 21c-7.605 0-10.804-8.296-10.937-8.648L.932 12l.131-.352C1.196 11.295 4.394 3 12 3s10.804 8.296 10.937 8.648l.131.352-.131.352C22.804 12.705 19.606 21 12 21zm-8.915-9c.658 1.467 3.5 7 8.915 7s8.257-5.533 8.915-7c-.658-1.467-3.5-7-8.915-7s-8.257 5.533-8.915 7zM12 16c-2.206 0-4-1.794-4-4s1.794-4 4-4 4 1.794 4 4-1.794 4-4 4zm0-6c-1.103 0-2 .897-2 2s.897 2 2 2 2-.897 2-2-.897-2-2-2z"></path>
# ...
# </article>
# <article class="card flat-card t-16 md-t-22 has-img ctype-story" id="item-1647178">
# <figure class="item-media">
# <a href="/kosmos/story/1647178/i-pio-molysmeni-poli-ston-kosmo-vrisketai-stin-kina-kai-kataskevazei-ypologistes">
# <picture>
# <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/8b8f1bbf-china-town-poli.jpg?t=6GKeXT9548Qt5PawJNsFcw"/>
# <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/8b8f1bbf-china-town-poli.jpg?t=6GKeXT9548Qt5PawJNsFcw"/>
# <img alt="Η πιο μολυσμένη πόλη στον κόσμο βρίσκεται στην Κίνα και κατασκευάζει υπολογιστές" class="item-image" height="80" loading="lazy" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/8b8f1bbf-china-town-poli.jpg?t=6GKeXT9548Qt5PawJNsFcw" width="132"/>
# </picture>
# </a>
# </figure>
# <div class="item-info">
# <h3 class="item-title">
# <a href="/kosmos/story/1647178/i-pio-molysmeni-poli-ston-kosmo-vrisketai-stin-kina-kai-kataskevazei-ypologistes">
# 							Η πιο μολυσμένη πόλη στον κόσμο βρίσκεται στην Κίνα και κατασκευάζει υπολογιστές						</a>
# </h3>
# <div class="item-details">
# <span class="item-category">ΚΟΣΜΟΣ</span>
# 				·
#
# 						<span class="item-date">
# 				1 ώρα			</span>
# </div>
# <div class="item-intro">
# 				Η εφιαλτική ζωή των εργατών που κατασκευάζουν τους φορητούς υπολογιστές σε μια μεγαλούπολη της Κίνας			</div>
# </div>
# </article>
# <article class="card flat-card t-16 md-t-22 has-img ctype-story" id="item-1647177">
# <figure class="item-media">
# <a href="/kosmos/story/1647177/oi-pio-epodynoi-tropoi-ektelesis-en-meso-methodou-pou-epilegei-enas-thanatopoinitis">
# <picture>
# <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/f49f7289-karekla.jpg?t=EG_B-YJ6jX4GHnFzoIPX1Q"/>
# <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/f49f7289-karekla.jpg?t=EG_B-YJ6jX4GHnFzoIPX1Q"/>
# <img alt="Οι πιο επώδυνοι τρόποι εκτέλεσης εν μέσω μεθόδου που επιλέγει ένας θανατοποινίτης" class="item-image" height="80" loading="lazy" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/f49f7289-karekla.jpg?t=EG_B-YJ6jX4GHnFzoIPX1Q" width="132"/>
# </picture>
# </a>
# </figure>
# <div class="item-info">
# <h3 class="item-title">
# <a href="/kosmos/story/1647177/oi-pio-epodynoi-tropoi-ektelesis-en-meso-methodou-pou-epilegei-enas-thanatopoinitis">
# 							Οι πιο επώδυνοι τρόποι εκτέλεσης εν μέσω μεθόδου που επιλέγει ένας θανατοποινίτης						</a>
# </h3>
# <div class="item-details">
# <span class="item-category">ΚΟΣΜΟΣ</span>
# 				·
#
# 						<span class="item-date">
# 				1 ώρα			</span>
# </div>
# <div class="item-intro">
# 				Ειδικοί έχουν εκφράσει τις απόψεις τους για μερικές από τις πιο συνηθισμένες μεθόδους εκτέλεσης στις ΗΠΑ, παρά το γεγονός ότι…			</div>
# </div>
# </article>
# <article class="card flat-card t-16 md-t-22 has-img ctype-story" id="item-1647176">
# <figure class="item-media">
# <a href="/kairos/story/1647176/kairos-synagermos-sti-makedonia-gia-xalazi-pote-tha-xtypisei">
# <picture>
# <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/c55539d9-1746511994375-203232150-Clipboard_05-06-2025_01.jpg?t=kQm9Hf-NMjLB3kYgPlVqWA"/>
# <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/c55539d9-1746511994375-203232150-Clipboard_05-06-2025_01.jpg?t=kQm9Hf-NMjLB3kYgPlVqWA"/>
# <img alt="Καιρός: Συναγερμός στη Μακεδονία για χαλάζι - Πότε θα «χτυπήσει»" class="item-image" height="80" loading="lazy" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/c55539d9-1746511994375-203232150-Clipboard_05-06-2025_01.jpg?t=kQm9Hf-NMjLB3kYgPlVqWA" width="132"/>
# </picture>
# </a>
# </figure>
# <div class="item-info">
# <h3 class="item-title">
# <a href="/kairos/story/1647176/kairos-synagermos-sti-makedonia-gia-xalazi-pote-tha-xtypisei">
# 							Καιρός: Συναγερμός στη Μακεδονία για χαλάζι - Πότε θα «χτυπήσει»						</a>
# </h3>
# <div class="item-details">
# <span class="item-category">ΚΑΙΡΟΣ</span>
# 				·
#
# 						<span class="item-date">
# 				1 ώρα			</span>
# </div>
# <div class="item-intro">
# 				Μεγάλη προσοχή τις επόμενες ώρες			</div>
# </div>
# </article>
# </div>
# <div class="pagination-section">
# <div class="pagination lines">
# <span class="nav-page">
# <span class="nav-text">Σελίδα </span>
# <span class="nav-number">1</span>
# </span>
# <a class="nav-link next-page" data-rel="next" href="/oles-oi-eidhseis?page=2">
# <span class="nav-text">Σελίδα </span>
# <span class="nav-number">2</span>
# </a>
# <a class="nav-link nav-icon next-page" href="/oles-oi-eidhseis?page=2">
# <svg class="icon-arrow arrow-right" height="32" width="32"><use xlink:href="#icon-arrow"></use></svg>
# <span class="nav-text">Επόμενη</span>
# </a>
# </div>
# </div>
# </div>
# <div class="grid-col side-col">
# <div class="side-blocks">
# <div class="side-block">
# <!-- Newsbomb_Rectangle_1 -->
# <div class="ad-unit-block">
# <div class="js-ad-slot ad-unit" data-params='{"name":"slot_Newsbomb_Rectangle_1","slot":"Newsbomb_Rectangle_1","publisher":"4773257","sizes":[[300,250],[300,600]],"position":"ad-position-259","collapse":false,"size_mapping":[],"devices":["desktop"],"fluid":1}' id="ad-position-259"></div>
# </div>
# </div>
# <div class="side-block">
# <!-- Newsbomb_Rectangle_2 -->
# <div class="ad-unit-block">
# <div class="js-ad-slot ad-unit" data-params='{"name":"slot_Newsbomb_Rectangle_2","slot":"Newsbomb_Rectangle_2","publisher":"4773257","sizes":[[300,250],[300,600]],"position":"ad-position-260","collapse":false,"size_mapping":[],"devices":["desktop"],"fluid":1}' id="ad-position-260"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-section banner-section">
# <!-- Newsbomb_Leaderboard_2 -->
# <div class="ad-unit-block">
# <div class="js-ad-slot ad-unit" data-params='{"name":"slot_Newsbomb_Leaderboard_2","slot":"Newsbomb_Leaderboard_2","publisher":"4773257","sizes":[[728,90],[970,250]],"position":"ad-position-252","collapse":false,"size_mapping":["[1024,600],[[728,90],[970,250]]","[760,600],[[728,90]]"],"devices":["tablet","desktop"],"fluid":0}' id="ad-position-252"></div>
# </div>
# </div>
# <div class="page-sections">
# <div class="page-section footer-section">
# <footer class="site-footer" id="footer">
# <div class="footer-columns">
# <div class="footer-newsletter">
# <div class="newsletter-box" id="module-148">
# <div class="block-head">
# <h2 class="block-title">
# <svg class="icon-newsletter" height="22" width="22">
# <use xlink:href="#icon-newsletter"></use>
# </svg>
# 			Newsletter
# 		</h2>
# <p>Πρωινή Eνημέρωση</p>
# </div>
# <form action="/index.php">
# <div class="form-field">
# <label for="newsletter-email-footer">Email</label>
# <input id="newsletter-email-footer" name="email" placeholder="Διεύθυνση Email" required="required" type="email">
# </input></div>
# <div class="form-terms">
# <div>
# <input id="newsletter-terms-footer" name="terms" required="" type="checkbox">
# <label for="newsletter-terms-footer">Έχω διαβάσει, κατανοώ και αποδέχομαι τους <a href="/oroi-xrisis" target="_blank">όρους χρήσης</a> του ιστότοπου της εταιρείας</label>
# </input></div>
# <div>
# <input id="newsletter-age-footer" name="over18" required="" type="checkbox">
# <label for="newsletter-age-footer">Δηλώνω υπεύθυνα ότι είμαι άνω των 18 ετών ή ότι βρίσκομαι υπό την εποπτεία γονέα ή κηδεμόνα ή επιτρόπου</label>
# </input></div>
# </div>
# <div class="form-action">
# <button class="btn" type="submit">
# 				ΚΑΝΕ ΕΓΓΡΑΦΗ
# 				<svg class="icon-arrow arrow-right" height="16" width="16"><use xlink:href="#icon-arrow"></use></svg>
# </button>
# </div>
# <input name="option" type="hidden" value="com_ajax"/>
# <input name="module" type="hidden" value="moosend"/>
# <input name="method" type="hidden" value="subscribe"/>
# <input name="format" type="hidden" value="json"/>
# <input name="id" type="hidden" value="148"/>
# </form>
# </div>
# </div>
# <div class="footer-meta">
# <div class="footer-logo">
# <a href="https://www.newsbomb.gr" title="Newsbomb">
# <svg height="46" width="290"><use xlink:href="#logo-newsbomb"></use></svg>
# </a>
# </div>
# <div class="site-social">
# <a class="social-icon icon-facebook" href="https://www.facebook.com/newsbombgr" rel="nofollow noopener" target="_blank" title="Facebook"><svg class="icon icon-facebook"><use xlink:href="#icon-facebook"></use></svg></a>
# <a class="social-icon icon-viber" href="https://invite.viber.com/?g2=AQABUUfRDwBnVVHgNFGmE%2FQgUdTpZXiv%2F4v3qAWVMQffJvIDpZ1ES1lvB6rA65jJ&amp;lang=el" rel="nofollow noopener" target="_blank" title="Viber"><svg class="icon icon-viber"><use xlink:href="#icon-viber"></use></svg></a>
# <a class="social-icon icon-instagram" href="https://www.instagram.com/newsbombgr/" rel="nofollow noopener" target="_blank" title="Instagram"><svg class="icon icon-instagram"><use xlink:href="#icon-instagram"></use></svg></a>
# <a class="social-icon icon-x" href="https://twitter.com/newsbombgr" rel="nofollow noopener" target="_blank" title="X(Twitter)"><svg class="icon icon-x"><use xlink:href="#icon-x"></use></svg></a>
# <a class="social-icon icon-youtube" href="https://www.youtube.com/channel/UCiZ5gd_RCuHipTJQm-2e8kw?sub_confirmation=1" tabindex="-1" target="_blank" title="Youtube Channel Newsbomb"><svg class="icon icon-youtube"><use xlink:href="#icon-youtube"></use></svg></a>
# <a class="social-icon icon-rss" href="/oles-oi-eidhseis?format=feed&amp;type=rss" target="_blank" title="RSS Feed"><svg class="icon icon-rss"><use xlink:href="#icon-rss"></use></svg></a>
# </div>
# </div>
# </div>
# <nav class="main-menu">
# <ul class="pillars">
# <li><a href="/about">Ταυτότητα</a></li>
# <li><a href="/oroi-xrisis">Όροι Χρήσης</a></li>
# <li><a href="/confidentiality">Δήλωση Εχεμύθειας</a></li>
# <li><a href="/code-of-conduct">Κώδικας Δεοντολογίας</a></li>
# <li><span class="is-link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} ); return false;">Ρυθμίσεις Cookies</span></li>
# <li><a href="/anti-bribery-policy">Anti - Bribery Policy</a></li>
# <li><a href="/contact">Επικοινωνία</a></li>
# <li><a href="/diafimisi">Διαφήμιση</a></li>
# </ul>
# </nav>
# </footer>
# </div>
# </div>
# <div class="page-section dpg-network-section">
# <div class="dpg-network">
# <div class="network-logo">
# <a class="logo-dpg" href="https://www.dpgmediagroup.gr/" rel="noopener" target="_blank" title="DPG Digital Media Group">
# <img alt="DPG Digital Media Group" height="100" loading="lazy" src="https://img.bbmd.gr/assets/network/dpg.svg" width="300"/>
# </a>
# </div>
# <div class="network-sites">
# <ul>
# <li>
# <a href="https://www.gossip-tv.gr" rel="noopener" target="_blank" title="gossip-tv.gr">
# <img alt="Gossip-tv.gr" height="70" loading="lazy" src="https://img.bbmd.gr/assets/network/gossip-tv.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.onsports.gr" rel="noopener" target="_blank" title="onsports.gr">
# <img alt="Onsports.gr" height="65" loading="lazy" src="https://img.bbmd.gr/assets/network/onsports.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.queen.gr" rel="noopener" target="_blank" title="queen.gr">
# <img alt="Queen.gr" height="120" loading="lazy" src="https://img.bbmd.gr/assets/network/queen.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.astrology.gr" rel="noopener" target="_blank" title="astrology.gr">
# <img alt="Astrology.gr" height="30" loading="lazy" src="https://img.bbmd.gr/assets/network/astrology.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.mothersblog.gr" rel="noopener" target="_blank" title="mothersblog.gr">
# <img alt="Mothersblog.gr" height="50" loading="lazy" src="https://img.bbmd.gr/assets/network/mothersblog.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.onmed.gr" rel="noopener" target="_blank" title="onmed.gr">
# <img alt="Onmed.gr" height="60" loading="lazy" src="https://img.bbmd.gr/assets/network/onmed.svg" width="300"/>
# </a>
# </li>
# <li>
# <a href="https://www.ratpack.gr" rel="noopener" target="_blank" title="ratpack.gr">
# <img alt="Ratpack.gr" height="55" loading="lazy" src="https://img.bbmd.gr/assets/network/ratpack.svg" width="247"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="network-credits">
# <div class="credits">
# <a href="http://www.ened.gr/" rel="noopener" target="_blank" title="ΕΝΕΔ">
# <span>Μέλος</span>
# <img alt="ened" class="ened" height="49" loading="lazy" src="https://img.bbmd.gr/assets/network/ened.png" width="200"/>
# </a>
# <br/>
# <a href="https://www.dpgmediagroup.gr/" rel="noopener" target="_blank" title="DPG Digital Media">Monetized by DPG Digital Media Group</a>
# </div>
# <div class="copyrights" data-nosnippet="true">©2012-2025 Newsbomb.gr - All rights reserved</div>
# </div>
# <div class="publisher-details">
# <div>
# <b>Επωνυμία:</b> GSTE ELECTRONIC PUBLICATIONS LIMITED, <b>Διακριτικός τίτλος:</b> GSTE ELECTRONIC PUBLICATIONS LIMITED, <b>Έδρα Επιχείρησης:</b> Σολωμού 70 &amp; Βάκχου 30 Μεταμόρφωση, Νομική μορφή επιχείρησης: Ελληνικό Υποκατάστημα Αλλοδαπής Εταιρείας, ΑΦΜ – ΔΟΥ: 997434600 ΔΟΥ ΦΑΕ Αθηνών, <b>Στοιχεία επικοινωνίας:</b> Σολωμού 70 &amp; Βάκχου 30 Μεταμόρφωση, 14451, 2106251412, info@newsbomb.gr, <b>Ιδιοκτήτης:</b> Γεωργία Νικολάου, <b>Νόμιμη εκπρόσωπος / Διαχειρίστρια:</b> Γεωργία Νικολάου, <b>Διευθύντρια:</b> Αμαλία Κάτζου, <b>Διευθύντρια σύνταξης:</b> Διονυσία Προκόπη, Δικαιούχος domain name: ZYRIANO LIMITED
# 			</div>
# <div class="logo-mht" style="">
# <img alt="" height="52" loading="lazy" src="https://img.bbmd.gr/assets/network/mt-gov-logo.png" style="max-width: 100%; height: auto; padding-right: 1em; box-sizing: border-box;" width="45"/>
# <span>Αριθμός Πιστοποίησης Μ.Η.Τ. 242188</span>
# </div>
# </div>
# </div>
# </div>
# <div class="fullscreen without-ads" id="modal">
# <div class="modal-overlay"></div>
# <button class="close-modal">
# <svg class="symbol modal-close" height="30" width="30"><use xlink:href="#icon-close"></use></svg>
# </button>
# <div class="modal-stage">
# <img alt="photo" class="modal-image" src="...">
# <button class="nav-button previous-button">
# <svg class="symbol" height="16" width="16"><use xlink:href="#icon-arrow"></use></svg>
# </button>
# <button class="nav-button next-button">
# <svg class="symbol" height="16" width="16"><use xlink:href="#icon-arrow"></use></svg>
# </button>
# </img></div>
# <div class="modal-toolbar">
# <div class="modal-info">
# <div class="photo-details">
# <div class="photo-num"></div>
# <div class="photo-description"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- Meta Pixel Code -->
# <script>
# window.setTimeout(function() {
# 	!function(f,b,e,v,n,t,s)
# 	{if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 	n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 	if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 	n.queue=[];t=b.createElement(e);t.async=!0;
# 	t.src=v;s=b.getElementsByTagName(e)[0];
# 	s.parentNode.insertBefore(t,s)}(window, document,'script',
# 	'https://connect.facebook.net/en_US/fbevents.js');
# 	fbq('init', '1222033684628167');
# 	fbq('track', 'PageView');
# }, 3000);
# </script>
# <!-- End Meta Pixel Code -->
# <script>
#
# 	const el = document.querySelector(".header-section");
# 	if (el)
# 	{
# 		const observer = new IntersectionObserver(
# 		([e]) => e.target.classList.toggle("is-pinned", e.intersectionRatio < 1),
# 		{ threshold: [1], rootMargin: '0px 200px 0px 200px' }
# 		);
# 		observer.observe(el);
# 	}
# </script>
# <dialog class="mini-dialog" id="read-later-modal">
# <div class="mini-modal-position">
# <div class="mini-modal">
# <span id="read-later-messsage"></span> <a href="/read-later-list">Δείτε τη λίστα σας</a>
# </div>
# </div>
# </dialog>
# <dialog class="mini-dialog" id="newsletter-modal">
# <div class="mini-modal-position">
# <div class="mini-modal">
# <span id="newsletter-module-response"></span>
# </div>
# </div>
# </dialog>
# <svg aria-hidden="true" focusable="false" style="width:0;height:0;position:absolute;">
# <lineargradient id="icon-gradient" x2="1" y2="1">
# <stop offset="0%" stop-color="#C31A20"></stop>
# <stop offset="50%" stop-color="#112266"></stop>
# <stop offset="100%" stop-color="#EA4335"></stop>
# </lineargradient>
# </svg>
# <script>
# const members = localStorage.getItem("enableMembers");
# if (members) {
# 	const membersContainer = document.querySelector("#members-container");
# 	if (membersContainer) {
# 		membersContainer.style.display = "block";
# 	}
# 	const itemComments = document.querySelector("#item-comments");
# 	if (itemComments) {
# 		itemComments.style.display = "block";
# 	}
# }
# </script>
# </body>
# </html>

# %%
articlesL = soup.find("div",{"class":"page-section news-items-section"}).find_all("article")
print(len(articlesL))
# Out:
# 30

# %%
article = articlesL[0]
print(article.prettify())
# Out:
# <article class="card flat-card t-16 md-t-22 has-img ctype-story" id="item-1647203">
#  <figure class="item-media">
#   <a href="/politikh/story/1647203/papastergiou-se-liges-ores-erxetai-o-prosopikos-arithmos-ti-eipe-gia-tin-aksiologisi-sto-dimosio">
#    <picture>
#     <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw"/>
#     <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw"/>
#     <img alt="Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικός αριθμός – Τι είπε για την αξιολόγηση στο Δημόσιο" class="item-image" height="80" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw" width="132"/>
#    </picture>
#   </a>
#  </figure>
#  <div class="item-info">
#   <h3 class="item-title">
#    <a href="/politikh/story/1647203/papastergiou-se-liges-ores-erxetai-o-prosopikos-arithmos-ti-eipe-gia-tin-aksiologisi-sto-dimosio">
#     Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικός αριθμός – Τι είπε για την αξιολόγηση στο Δημόσιο
#    </a>
#   </h3>
#   <div class="item-details">
#    <span class="item-category">
#     ΠΟΛΙΤΙΚΗ
#    </span>
#    ·
#    <span class="item-date">
#     1 λεπτό
#    </span>
#   </div>
#   <div class="item-intro">
#    Θέμα ωρών να βγει στον «αέρα» ο προσωπικός αριθμός, όπως προανήγγειλε ο υπουργός Ψηφιακής Διακυβέρνησης
#   </div>
#  </div>
# </article>

# %%
title = article.find("h3", {"class": "item-title"}).text.strip()
title
# Out:
# 'Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικός αριθμός – Τι είπε για την αξιολόγηση στο Δημόσιο'

# %%
url = article.find("a")["href"]
url
# Out:
# '/politikh/story/1647203/papastergiou-se-liges-ores-erxetai-o-prosopikos-arithmos-ti-eipe-gia-tin-aksiologisi-sto-dimosio'

# %%
datetime_str = article.find(class_="item-date")  #Το inspect δεν έδινε ακριβή ημερομηνία και ώρα
datetime_str = datetime_str.text.strip()
datetime_str
# Out:
# '1 λεπτό'

# %%
author_element = article.find("a", {"class": "item-author"})

if author_element:
    author = author_element.text.strip()
else:
    author = "N/A"
author
# Out:
# 'N/A'

# %%
section = article.find("span",{"class":"item-category"})
section
# Out:
# <span class="item-category">ΠΟΛΙΤΙΚΗ</span>

# %%
section = article.find("span",{"item-category"})  #Το έκανα δύο φορές με δυο διαφορετικούς τρόπους, καθώς δεν ήξερα τι και ποιο είναι το σωστό
section
section = section.text.strip()
section
# Out:
# 'ΠΟΛΙΤΙΚΗ'

# %%
section = article.find("a"),{"class":"item-category"}
section
# Out:
# (<a href="/politikh/story/1647203/papastergiou-se-liges-ores-erxetai-o-prosopikos-arithmos-ti-eipe-gia-tin-aksiologisi-sto-dimosio">
#  <picture>
#  <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw"/>
#  <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw"/>
#  <img alt="Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικός αριθμός – Τι είπε για την αξιολόγηση στο Δημόσιο" class="item-image" height="80" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/e95d7a02-dimitris-papastergiou.jpg?t=KyduYS24wAncmrB2qlvcnw" width="132"/>
#  </picture>
#  </a>,
#  {'class': 'item-category'})

# %%
excerpt = article.find("div", {"class":"item-intro"}).text.strip()
excerpt
# Out:
# 'Θέμα ωρών να βγει στον «αέρα» ο προσωπικός αριθμός, όπως προανήγγειλε ο υπουργός Ψηφιακής Διακυβέρνησης'

# %%
def get_teaser_elements_from_articlesL(articlesL):
    articles_dataL = []
    for article in articlesL:
        # Title
        try:
            title = article.find("h3", {"class": "item-title"}).find("a").text.strip()
        except:
            title = ""


        try:
            article_url = article.find("h3", {"class": "item-title"}).find("a")["href"]
        except:
            article_url = ""


        try:
            date_str = article.find("span", {"class": "item-date"}).text.strip()
            time_str = ""
        except:
            date_str = ""
            time_str = ""

        try:
            section = article.find("span", {"class": "item-category"}).text.strip()
        except:
            section = ""

        # Excerpt
        try:
            excerpt = article.find("div", {"class": "item-intro"}).text.strip()
        except:
            excerpt = ""

        author = ""

        articleD = {
            "title": title,
            "article_url": article_url,
            "date": date_str,
            "time": time_str,
            "section": section,
            "excerpt": excerpt,
            "author": author
        }

        articles_dataL.append(articleD)

    return articles_dataL

# %%
import pandas as pd

articles_dataL = get_teaser_elements_from_articlesL(articlesL)
df = pd.DataFrame(articles_dataL)
df
# Out:
#                                                 title  \
# 0   Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικ...
# 1   Τα «Φαντάσματα του ελληνικού κινηματογράφου» μ...
# 2   Οι αγώνες ρεβάνς των Κυπέλλων Ευρώπης με σούπε...
# 3   Κατερίνα Καινούργιου: Ο λόγος που έφυγε εκτάκτ...
# 4   «Ο σκύλος της οικογένειας Τσιτσιπά τον άρπαξε ...
# 5   «Ελευθέριος Βενιζέλος»: Αυξημένη κατά 9% η επι...
# 6   Comicdom CON Athens 2025: Έρχεται η μεγάλη γιο...
# 7   Σιωπηλός θάνατος στον αέρα που αναπνέουμε – Πρ...
# 8   Ρόδος: Ζευγάρια τουριστών τσακώθηκαν μεταξύ το...
# 9   Αθλητικές μεταδόσεις: Πού θα δείτε Παναθηναϊκό...
# 10  Τραγωδία στη Νεμέα: Νεκρός αγρότης που καταπλα...
# 11  Μαρίνα Σπανού: Καλοκαιρινές ιστορίες σε όλη τη...
# 12  Ώρα μηδέν για τον 267ο Πάπα: Τα κονκλάβια ανά ...
# 13  Kυρίαρχος μπροστά στον κόσμο του με τον Χουάντ...
# 14  Επίθεση σκύλου στη Βουλιαγμένη: Ανήκει στην οι...
# 15  Μερομήνια: Τι «λένε» για το φετινό καλοκαίρι -...
# 16  Κοντογεώργης: «Οι πολιτικές μας απευθύνονται σ...
# 17  Ρόδος: Ανήλικη που απείλησε συμμαθητές της με ...
# 18  Αδιανόητη βλασφημία: Ειδικός «αποκάλυψε» πως ο...
# 19  Παρτιζάν: Πήρε θέση για το άγριο ξύλο παικτών ...
# 20  Σχολεία: Πότε ξεκινούν οι προαγωγικές εξετάσει...
# 21  Έτοιμη για λανσάρισμα η ηλεκτρική Mercedes-Ben...
# 22  Άνοια: Το «σιωπηλό» σημάδι που εμφανίζεται στο...
# 23  Πάτρα: 60χρονη έριξε κουβά με νερό και χλωρίνη...
# 24  Ίντερ - Μπαρτσελόνα: Μάχη για μια θέση στον τε...
# 25  Η «Ανάσταση» των κόκκινων τζιτζικιών: Έρχονται...
# 26  Θρήνος στην Αργεντινή: Πέθανε ο «μαέστρος» και...
# 27  Η πιο μολυσμένη πόλη στον κόσμο βρίσκεται στην...
# 28  Οι πιο επώδυνοι τρόποι εκτέλεσης εν μέσω μεθόδ...
# 29  Καιρός: Συναγερμός στη Μακεδονία για χαλάζι - ...
#
#                                           article_url      date time  \
# 0   /politikh/story/1647203/papastergiou-se-liges-...   1 λεπτό
# 1   /politismos/story/1647202/ta-fantasmata-tou-el...   2 λεπτά
# 2   /sports/pame-stoihima/story/1647200/oi-agones-...   3 λεπτά
# 3   /media-agb/story/1647199/katerina-kainoyrgiou-...   4 λεπτά
# 4   /ellada/story/1647198/o-skylos-tis-oikogeneias...  10 λεπτά
# 5   /ellada/story/1647197/eleftherios-venizelos-af...  12 λεπτά
# 6   /politismos/story/1647196/comicdom-con-athens-...  13 λεπτά
# 7   /ygeia/story/1647195/siopilos-thanatos-ston-ae...  13 λεπτά
# 8   /ellada/story/1647194/rodos-zevgaria-touriston...  17 λεπτά
# 9   /sports/story/1647193/athlitikes-metadoseis-po...  18 λεπτά
# 10  /ellada/story/1647192/tragodia-sti-nemea-nekro...  23 λεπτά
# 11  /politismos/story/1647191/marina-spanoy-kaloka...  25 λεπτά
# 12  /kosmos/story/1647183/ora-miden-gia-ton-267o-p...  35 λεπτά
# 13  /sports/pame-stoihima/story/1647025/kyriarxos-...  35 λεπτά
# 14  /ellada/story/1647190/epithesi-skylou-sti-voul...  36 λεπτά
# 15  /kairos/story/1647189/merominia-ti-lene-gia-to...  38 λεπτά
# 16  /politikh/story/1647188/kontogeorgis-oi-politi...  45 λεπτά
# 17  /ellada/story/1647187/rodos-aniliki-pou-apeili...  52 λεπτά
# 18  /kosmos/story/1647186/adianoiti-vlasfimia-eidi...  52 λεπτά
# 19  /sports/mpasket/story/1647185/partizan-pire-th...  52 λεπτά
# 20  /paideia/story/1647126/sxoleia-pote-ksekinoyn-...  53 λεπτά
# 21  /aftokinito/story/1647152/etoimi-gia-lansarism...  55 λεπτά
# 22  /ygeia/story/1647184/anoia-to-siopilo-simadi-p...  56 λεπτά
# 23  /ellada/story/1647182/patra-60xroni-erikse-kou...     1 ώρα
# 24  /sports/podosfairo/story/1647181/inter-bartsel...     1 ώρα
# 25  /kosmos/story/1647180/i-anastasi-ton-kokkinon-...     1 ώρα
# 26  /sports/podosfairo/story/1647179/thrinos-stin-...     1 ώρα
# 27  /kosmos/story/1647178/i-pio-molysmeni-poli-sto...     1 ώρα
# 28  /kosmos/story/1647177/oi-pio-epodynoi-tropoi-e...     1 ώρα
# 29  /kairos/story/1647176/kairos-synagermos-sti-ma...     1 ώρα
#
#        section                                            excerpt author
# 0     ΠΟΛΙΤΙΚΗ  Θέμα ωρών να βγει στον «αέρα» ο προσωπικός αρι...
# 1   ΠΟΛΙΤΙΣΜΟΣ  Το αφιέρωμα της ΕΣΠΕΚ «Φαντάσματα: μια συναρπα...
# 2     ΣΤΟΙΧΗΜΑ  Ίντερ-Μπαρτσελόνα και Παρί Σεν Ζερμέν-Άρσεναλ ...
# 3    LIFESTYLE  Η Κατερίνα Καινούργιου για την περιπέτεια με τ...
# 4       ΕΛΛΑΔΑ  Ο 71χρονος μεταφέρθηκε στο Γενικό Νοσοκομείο Α...
# 5       ΕΛΛΑΔΑ  Οι επιβάτες ανέρχονται σε 2,71 εκατομύρια έναν...
# 6   ΠΟΛΙΤΙΣΜΟΣ  Το Comicdom CON Athens 2025 διεξάγεται στην Τε...
# 7        ΥΓΕΙΑ  Ο Aspergillus βρίσκεται παντού γύρω μας – στον...
# 8       ΕΛΛΑΔΑ  Ζευγάρια τουριστών τσακώθηκαν κι όταν ο φίλος ...
# 9     ΑΘΛΗΤΙΚΑ  Δείτε το αναλυτικό πρόγραμμα με τις LIVE αθλητ...
# 10      ΕΛΛΑΔΑ  Θανατηφόρο δυστύχημα σημειώθηκε σε κοινότητα τ...
# 11  ΠΟΛΙΤΙΣΜΟΣ  Όλοι οι σταθμοί της καλοκαιρινής περιοδείας τη...
# 12      ΚΟΣΜΟΣ  Το Κονκλάβιο συνέρχεται αύριο (7/5) για να εκλ...
# 13    ΣΤΟΙΧΗΜΑ  Οι «πράσινοι» έκαναν πράξη την υπόσχεση που εί...
# 14      ΕΛΛΑΔΑ  Το περιστατικό σημειώθηκε όταν ένας 71χρονος ά...
# 15      ΚΑΙΡΟΣ  Επιτέλους φαίνεται πως θα έχουμε ένα «γλυκό» κ...
# 16    ΠΟΛΙΤΙΚΗ  Από το τελευταίο, εν εξελίξει, κύμα δημοσκοπήσ...
# 17      ΕΛΛΑΔΑ  Βίαιο περιστατικό στο ΕΠΑΛ Ρόδου λίγες ώρες με...
# 18      ΚΟΣΜΟΣ  Αδιανόητες κουβέντες από τον σκηνοθέτη ντοκιμα...
# 19     ΜΠΑΣΚΕΤ  Η Παρτιζάν εξέδωσε ανακοίνωσε για το επεισόδιο...
# 20     ΠΑΙΔΕΙΑ  Στην τελική ευθεία για τη λήξη των μαθημάτων σ...
# 21  ΑΥΤΟΚΙΝΗΤΟ  Η Mercedes-Benz επιβεβαίωσε ότι θα παρουσιάσει...
# 22       ΥΓΕΙΑ  Το φαινόμενο αυτό είναι γνωστό και ως «dementi...
# 23      ΕΛΛΑΔΑ  Η κοπέλα έντρομη έβαλε τις φωνές, και ευτυχώς ...
# 24  ΠΟΔΟΣΦΑΙΡΟ  Πού θα δείτε τον σπουδαίο ημιτελικό του Champi...
# 25      ΚΟΣΜΟΣ  Η επιστημονική κοινότητα παρακολουθεί στενά το...
# 26  ΠΟΔΟΣΦΑΙΡΟ  Θλίψη στην οικογένεια της Ταγιέρες και της Αργ...
# 27      ΚΟΣΜΟΣ  Η εφιαλτική ζωή των εργατών που κατασκευάζουν ...
# 28      ΚΟΣΜΟΣ  Ειδικοί έχουν εκφράσει τις απόψεις τους για με...
# 29      ΚΑΙΡΟΣ                   Μεγάλη προσοχή τις επόμενες ώρες

# %%
def scrape_newsbomb_teaser_pages(archive_name, start_page_nbr, end_page_nbr):
  all_articles_dataL = []

  print(f"\rScraping started", end="")

  for page_nbr in range(start_page_nbr, end_page_nbr+1):

    url = f"https://www.newsbomb.gr/{archive_name}/?pg=/{page_nbr}/"

    print(f"\rScraping page {page_nbr}: {url}" + " "*20, end="")

    soup = get_webpage_soup(url)
    articlesL = soup.find("div", {"class": "page-section news-items-section"}).find_all("article")

    page_articles_dataL = get_teaser_elements_from_articlesL(articlesL)

    all_articles_dataL.extend(page_articles_dataL)

    delay = random.uniform(1, 3)

    time.sleep(delay)

  all_articles_df = pd.DataFrame(all_articles_dataL)
  print(f"\rScraping completed. Fetshed {len(all_articles_df)} articles.")

  return all_articles_df

# %%
def scrape_newsbomb_teaser_pages(archive_name, start_page_nbr=1, end_page_nbr=1):
    all_articles_dataL = []
    base_url = f"https://www.newsbomb.gr/{archive_name}"

    print(f"\rScraping started for {archive_name}", end="")

    for page_nbr in range(start_page_nbr, end_page_nbr + 1):
        url = f"{base_url}?page={page_nbr}" if page_nbr > 1 else base_url
        print(f"\rScraping page {page_nbr}: {url.ljust(80)}", end="")

        soup = get_webpage_soup(url)
        if not soup:
            continue


        articles_container = soup.find("div", class_="page-section news-items-section") or \
                           soup.find("div", class_="articles-list") or \
                           soup.find("div", class_="news-items")

        if not articles_container:
            print(f"\nNo articles container found on page {page_nbr}")
            continue

        articlesL = articles_container.find_all("article", class_=lambda x: x and 'card' in x) or \
                   articles_container.find_all("article")

        if not articlesL:
            print(f"\nNo articles found on page {page_nbr}")
            continue

        page_articles_dataL = get_teaser_elements_from_articlesL(articlesL)
        all_articles_dataL.extend(page_articles_dataL)

        delay = random.uniform(1.5, 4)

        time.sleep(delay)

    all_articles_df = pd.DataFrame(all_articles_dataL)
    print(f"\rScraping completed. Fetched {len(all_articles_df)} articles from {archive_name}.".ljust(100))

    return all_articles_df

# %%
trump_df = scrape_newsbomb_teaser_pages("search/?q=trump", 1, 2)
trump_df
# Out:
# Scraping page 1: https://www.newsbomb.gr/search/?q=trump                                         https://www.newsbomb.gr/search/?q=trump was scraped successfully
#
# No articles found on page 1
# Scraping page 2: https://www.newsbomb.gr/search/?q=trump?page=2                                  https://www.newsbomb.gr/search/?q=trump?page=2 was scraped successfully
#
# No articles found on page 2
# Scraping completed. Fetched 0 articles from search/?q=trump.
# Empty DataFrame
# Columns: []
# Index: []

# %%
category = "sports"

# %%
url2 = f"https://www.newsbomb.gr/{category}"

# %%
soup2 = get_webpage_soup(url2)
# Out:
# https://www.newsbomb.gr/sports was scraped successfully

# %%
articlesL2 = soup2.find("div", {"class": "page-section news-items-section"}).find_all("article")  if soup2.find("div", {"class": "page-section news-items-section"}) else soup2.find_all("article", class_=lambda x: x and 'card' in x)
print(len(articlesL2))
# Out:
# 25

# %%
article2 = articlesL2[0]
print(article2.prettify())
# Out:
# <article class="card flat-card t-16 md-t-22 has-img ctype-story" id="item-1647200">
#  <figure class="item-media">
#   <a href="/sports/pame-stoihima/story/1647200/oi-agones-revans-ton-kypellon-evropis-me-soyper-apodoseis-apo-to-pame-stoixima">
#    <picture>
#     <source media="(min-width: 768px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/12788fa5-inter-barcelona.jpg?t=ztfO1HRuPDfGmNMQDHaR6A"/>
#     <source media="(min-width: 0px)" srcset="https://img.bbmd.gr/img/500/max/90/2025/05/06/12788fa5-inter-barcelona.jpg?t=ztfO1HRuPDfGmNMQDHaR6A"/>
#     <img alt="Οι αγώνες ρεβάνς των Κυπέλλων Ευρώπης με σούπερ αποδόσεις από το Πάμε Στοίχημα" class="item-image" height="80" src="https://img.bbmd.gr/img/500/max/90/2025/05/06/12788fa5-inter-barcelona.jpg?t=ztfO1HRuPDfGmNMQDHaR6A" width="132"/>
#    </picture>
#   </a>
#  </figure>
#  <div class="item-info">
#   <h3 class="item-title">
#    <a href="/sports/pame-stoihima/story/1647200/oi-agones-revans-ton-kypellon-evropis-me-soyper-apodoseis-apo-to-pame-stoixima">
#     Οι αγώνες ρεβάνς των Κυπέλλων Ευρώπης με σούπερ αποδόσεις από το Πάμε Στοίχημα
#    </a>
#   </h3>
#   <div class="item-details">
#    <span class="item-category">
#     ΣΤΟΙΧΗΜΑ
#    </span>
#    ·
#    <span class="item-date">
#     13 λεπτά
#    </span>
#   </div>
#   <div class="item-intro">
#    Ίντερ-Μπαρτσελόνα και Παρί Σεν Ζερμέν-Άρσεναλ στο Champions League με αμέτρητες αγορές, ανανεωμένο Bet Builder και νέο Cash Out
#   </div>
#  </div>
# </article>

# %%
def get_teaser_elements_from_articlesL2(articlesL2):
    articles_dataL2 = []
    for article2 in articlesL2:
        try:
            # Τίτλος
            title_elem = article2.find('h3', class_='item-title')
            title = title_elem.get_text(strip=True) if title_elem else ""

            # URL άρθρου
            article_url = title_elem.find('a')['href'] if title_elem and title_elem.find('a') else ""
            if article_url and not article_url.startswith('http'):
                article_url = f"https://www.newsbomb.gr{article_url}"

            # Ημερομηνία
            date_elem = article2.find('span', class_='item-date')
            date_str = date_elem.get_text(strip=True) if date_elem else ""
            time_str = ""  # Δεν υπάρχει ξεχωριστή ώρα

            # Κατηγορία
            category_elem = article2.find('span', class_='item-category')
            section = category_elem.get_text(strip=True) if category_elem else ""

            # Περίληψη
            excerpt_elem = article2.find('div', class_='item-intro')
            excerpt = excerpt_elem.get_text(strip=True) if excerpt_elem else ""

            # Συγγραφέας (δεν υπάρχει στο newsbomb.gr)
            author = ""

            articleD2 = {
                "title": title,
                "article_url": article_url,
                "date": date_str,
                "time": time_str,
                "section": section,
                "excerpt": excerpt,
                "author": author  # Μόνο τα ζητούμενα πεδία
            }

            articles_dataL2.append(articleD2)

        except Exception as e:
            print(f"Σφάλμα επεξεργασίας άρθρου: {e}")
            continue

    return articles_dataL2

# %%
import random

def scrape_newsbomb_teaser_pages2(category, start_page_nbr, end_page_nbr):
  all_articles_dataL2 = []

  print(f"\rScraping started", end="")

  for page_nbr in range(start_page_nbr, end_page_nbr+1):
    url2= f"https://www.newsbomb.gr/{category}/?pg={page_nbr}"

    print(f"\rScraping page {page_nbr}: {url2}" + " "*20, end="")

    soup2 = get_webpage_soup(url2)


    if soup2 is None:
        print(f"Error: Could not retrieve content from {url2}")
        continue


    articles_container = soup2.find("div", {"class": "articles articles--singleColumn articles--large"}) or \
                          soup2.find("div", {"class": "page-section news-items-section"})

    if articles_container is None:
        print(f"Error: Could not find articles container on {url2}")
        continue

    articlesL2 = articles_container.find_all("article")

    page_articles_dataL2 = get_teaser_elements_from_articlesL2(articlesL2)

    all_articles_dataL2.extend(page_articles_dataL2)

    delay = random.uniform(1, 3)
    time.sleep(delay)

  all_articles_df2 = pd.DataFrame(all_articles_dataL2)
  print(f"\rScraping completed. Fetshed {len(all_articles_df2)} articles.")

  return all_articles_df2

# %%
sports_df = scrape_newsbomb_teaser_pages2("sports", 1, 3)
sports_df
# Out:
# Scraping page 1: https://www.newsbomb.gr/sports/?pg=1                    https://www.newsbomb.gr/sports/?pg=1 was scraped successfully
# Scraping page 2: https://www.newsbomb.gr/sports/?pg=2                    https://www.newsbomb.gr/sports/?pg=2 was scraped successfully
# Scraping page 3: https://www.newsbomb.gr/sports/?pg=3                    https://www.newsbomb.gr/sports/?pg=3 was scraped successfully
# Scraping completed. Fetshed 75 articles.
#                                                 title  \
# 0   Οι αγώνες ρεβάνς των Κυπέλλων Ευρώπης με σούπε...
# 1   Αθλητικές μεταδόσεις: Πού θα δείτε Παναθηναϊκό...
# 2   Kυρίαρχος μπροστά στον κόσμο του με τον Χουάντ...
# 3   Παρτιζάν: Πήρε θέση για το άγριο ξύλο παικτών ...
# 4   Ίντερ - Μπαρτσελόνα: Μάχη για μια θέση στον τε...
# ..                                                ...
# 70  Παναθηναϊκός AKTOR – Αναντολού Εφές: «Αυτό που...
# 71  BCL Final Four 2025: Αισιοδοξία για Μπράις στη...
# 72  Έπος: Η Λιντς πανηγύρισε με «ώπα» και… συρτάκι...
# 73  ΠΑΟΚ – ΑΕΚ: Με Μαρσιάλ στην Τούμπα η «Ένωση» |...
# 74  Στέφανος Τσιτσιπάς για το BCL Final Four 2025:...
#
#                                           article_url      date time  \
# 0   https://www.newsbomb.gr/sports/pame-stoihima/s...  59 λεπτά
# 1   https://www.newsbomb.gr/sports/story/1647193/a...     1 ώρα
# 2   https://www.newsbomb.gr/sports/pame-stoihima/s...    2 ώρες
# 3   https://www.newsbomb.gr/sports/mpasket/story/1...    2 ώρες
# 4   https://www.newsbomb.gr/sports/podosfairo/stor...    2 ώρες
# ..                                                ...       ...  ...
# 70  https://www.newsbomb.gr/sports/mpasket/story/1...   18 ώρες
# 71  https://www.newsbomb.gr/sports/mpasket/story/1...   19 ώρες
# 72  https://www.newsbomb.gr/sports/story/1647011/e...   20 ώρες
# 73  https://www.newsbomb.gr/sports/podosfairo/stor...   20 ώρες
# 74  https://www.newsbomb.gr/sports/mpasket/story/1...   21 ώρες
#
#        section                                            excerpt author
# 0     ΣΤΟΙΧΗΜΑ  Ίντερ-Μπαρτσελόνα και Παρί Σεν Ζερμέν-Άρσεναλ ...
# 1     ΑΘΛΗΤΙΚΑ  Δείτε το αναλυτικό πρόγραμμα με τις LIVE αθλητ...
# 2     ΣΤΟΙΧΗΜΑ  Οι «πράσινοι» έκαναν πράξη την υπόσχεση που εί...
# 3      ΜΠΑΣΚΕΤ  Η Παρτιζάν εξέδωσε ανακοίνωσε για το επεισόδιο...
# 4   ΠΟΔΟΣΦΑΙΡΟ  Πού θα δείτε τον σπουδαίο ημιτελικό του Champi...
# ..         ...                                                ...    ...
# 70     ΜΠΑΣΚΕΤ  Ο Εργκίν Αταμάν ξεκαθάρισε ότι το μόνο που τον...
# 71     ΜΠΑΣΚΕΤ  Ο Σι Τζέι Μπράις αναμένεται να βρίσκεται στη δ...
# 72    ΑΘΛΗΤΙΚΑ  Ξέφρενοι πανηγυρισμοί με… ελληνικό χρώμα για τ...
# 73  ΠΟΔΟΣΦΑΙΡΟ  Ο Αντονί Μαρσιάλ θα βρίσκεται στη διάθεση του ...
# 74     ΜΠΑΣΚΕΤ  Ο Στέφανος Τσιτσιπάς ευχήθηκε καλή επιτυχία στ...
#
# [75 rows x 7 columns]

# %%
politikh_df = scrape_newsbomb_teaser_pages2("politikh", 1, 2)
politikh_df
# Out:
# Scraping page 1: https://www.newsbomb.gr/politikh/?pg=1                    https://www.newsbomb.gr/politikh/?pg=1 was scraped successfully
# Scraping page 2: https://www.newsbomb.gr/politikh/?pg=2                    https://www.newsbomb.gr/politikh/?pg=2 was scraped successfully
# Scraping completed. Fetshed 50 articles.
#                                                 title  \
# 0   Zαχαράκη: Όποιος φοιτητής παίρνει μέρος σε επε...
# 1   Χρυσοχοΐδης: «Όποιος τραμπουκίζει, πρέπει να α...
# 2   Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπ
# 45  ΠΟΛΙΤΙΚΗ  Δύο υπουργοί έδωσαν στίγμα κατά την παρουσίαση...
# 46  ΠΟΛΙΤΙΚΗ                         Το μήνυμα του πρωθυπουργού
# 47  ΠΟΛΙΤΙΚΗ  «Κοινωνική εργασία» αντί αποβολών στα σχολεία,...
# 48  ΠΟΛΙΤΙΚΗ  «Η Ελλάδα έχει θέσει το ζήτημα του ψηφιακού εθ...
# 49  ΠΟΛΙΤΙΚΗ          Τα βάζει με τις πολυεθνικές ο Ανδρουλάκης

# %%
oikonomia_df = scrape_newsbomb_teaser_pages2("politikh", 1, 2)
oikonomia_df
# Out:
# Scraping page 1: https://www.newsbomb.gr/politikh/?pg=1                    https://www.newsbomb.gr/politikh/?pg=1 was scraped successfully
# Scraping page 2: https://www.newsbomb.gr/politikh/?pg=2                    https://www.newsbomb.gr/politikh/?pg=2 was scraped successfully
# Scraping completed. Fetshed 50 articles.
#                                                 title  \
# 0   Zαχαράκη: Όποιος φοιτητής παίρνει μέρος σε επε...
# 1   Χρυσοχοΐδης: «Όποιος τραμπουκίζει, πρέπει να α...
# 2   Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικ...
# 3   Κοντογεώργης: «Οι πολιτικές μας απευθύνονται σ...
# 4   Νίκος Παπαδόπουλος: «Δεν ξέρω γιατί με διέγραψ...
# 5   Εφιάλτης για την αντιπολίτευση οι νέες δημοσκο...
# 6   Δημοσκοπήσεις: Η πρώτη κάλπη βγάζει οργή και η...
# 7   Κικίλιας: Να μη μας κουνάνε το δάχτυλο οι κύρι...
# 8   Μητσοτάκης: Έρχονται πειθαρχικές συνέπειες για...
# 9   Θεοδωρικάκος για νέο αναπτυξιακό νόμο: Δημιουρ...
# 10  Eπίσκεψη του Μητσοτάκη στο Ραδιομέγαρο της ΕΡΤ...
# 11  Δημοσκόπηση Opinion Poll: Πρώτη η ΝΔ με 30% - ...
# 12  Νέα δημοσκόπηση: Οι νέοι «κρύβουν» τα περιστατ...
# 13  Μέγαρο Μαξίμου: Παρουσιάζεται την Τρίτη η πλατ...
# 14  Μπελέρης: «Ζητώ την αναθεώρηση των αποφάσεων π...
# 15  Νίκος Χαρδαλιάς: «Το ''δεν κάνω πίσω'' δεν είν...
# 16  Δένδιας στο CNN Insights: Οι προκλήσεις, να γί...
# 17  Διαγράφεται ο Νίκος Παπαδόπουλος από τη «Νίκη»...
# 18  Η εξειδίκευση των μέτρων για την καταπολέμηση ...
# 19  Δόμνα Μιχαηλίδου: Επίδομα και για ηλικίες 18 έ...
# 20  Χρυσοχοϊδης: Ήρθαν Σουηδοί να μας αντιγράψουν ...
# 21  Μητσοτάκης για επέτειο Marfin: Τα διδάγματα το...
# 22  Όλα τα μέτρα κατά της βίας και παραβατικότητας...
# 23  Σκέρτσος: «Σήμερα παραδίδεται το Kids Wallet» ...
# 24  Μέτωπο με την ακρίβεια ανοίγει σήμερα το ΠΑΣΟΚ...
# 25  Zαχαράκη: Όποιος φοιτητής παίρνει μέρος σε επε...
# 26  Χρυσοχοΐδης: «Όποιος τραμπουκίζει, πρέπει να α...
# 27  Παπαστεργίου: Σε λίγες ώρες έρχεται ο προσωπικ...
# 9   Για να επιλέξουν το όνομα, οι ερευνητές, με επ...
# 10  Ένας άνδρας συνελήφθη αφού πέρασε με το αυτοκί...
# 11  Γιατί ονομάζεται «Ελληνικός σταυρός» και τι ακ...
# 12  Οι κάτοικοι της περιοχής του Σικάγου κατέφυγαν...
# 13  Ο Όλαφ Σολτς παραδίδει την εξουσία στη Γερμανί...
# 14  Το Βατικανό θα διακόψει το τηλεφωνικό σήμα κατ...
# 15  Ένας από τους σωματοφύλακες της κόρης του Ντόν...
# 16  Τι κάνουν οι κάτοικοι αυτού του χωριού, ώστε ν...
# 17  Σύμφωνα με την παράδοση, το βαμβάκι επιτρέπει ...
# 18  Αυτός ο ήχος παράγεται μόνο από έναν άνθρωπο π...
# 19  Ποιο είναι το κόλπο που πρέπει να κάνετε με τα...
# 20  Η κολομβιανή νεοπαραστρατιωτική ομάδα Clan del...
# 21  Συνεχίζονται οι βομβαρδισμοί τους Ισραήλ σε θέ...
# 22  Το νέο περιστατικό έρχεται σε μια περίοδο αυξη...
# 23  Διακοπή τηλεφωνικών επικοινωνιών στη διάρκεια ...
# 24  Έλληνες τιμούν εκείνους που φυλακίστηκαν και β...
# 25  Ο Φρίντριχ Μερτς δέχτηκε ένα απροσδόκητο πλήγμ...
# 26  Κλιμακώνουν τις επιθέσεις τους Ουκρανία και Ρω...
# 27  Μερικοί κώνοι σχηματίστηκαν πριν από 3.820 χρό...
# 28  Το Κονκλάβιο συνέρχεται αύριο (7/5) για να εκλ...
# 29  Αδιανόητες κουβέντες από τον σκηνοθέτη ντοκιμα...
# 30  Η επιστημονική κοινότητα παρακολουθεί στενά το...
# 31  Η εφιαλτική ζωή των εργατών που κατασκευάζουν ...
# 32  Ειδικοί έχουν εκφράσει τις απόψεις τους για με...
# 33  Η Κιμ Καρντάσιαν δεν έκρυψε την οργή της όταν ...
# 34  Για να επιλέξουν το όνομα, οι ερευνητές, με επ...
# 35  Ένας άνδρας συνελήφθη αφού πέρασε με το αυτοκί...
# 36  Γιατί ονομάζεται «Ελληνικός σταυρός» και τι ακ...
# 37  Οι κάτοικοι της περιοχής του Σικάγου κατέφυγαν...
# 38  Ο Όλαφ Σολτς παραδίδει την εξουσία στη Γερμανί...
# 39  Το Βατικανό θα διακόψει το τηλεφωνικό σήμα κατ...
# 40  Ένας από τους σωματοφύλακες της κόρης του Ντόν...
# 41  Τι κάνουν οι κάτοικοι αυτού του χωριού, ώστε ν...
# 42  Σύμφωνα με την παράδοση, το βαμβάκι επιτρέπει ...
# 43  Αυτός ο ήχος παράγεται μόνο από έναν άνθρωπο π...
# 44  Ποιο είναι το κόλπο που πρέπει να κάνετε με τα...
# 45  Η κολομβιανή νεοπαραστρατιωτική ομάδα Clan del...
# 46  Συνεχίζονται οι βομβαρδισμοί τους Ισραήλ σε θέ...
# 47  Το νέο περιστατικό έρχεται σε μια περίοδο αυξη...
# 48  Διακοπή τηλεφωνικών επικοινωνιών στη διάρκεια ...
# 49  Έλληνες τιμούν εκείνους που φυλακίστηκαν και β...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
